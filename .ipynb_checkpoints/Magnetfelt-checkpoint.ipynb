# %%
import numpy as np
import matplotlib.pyplot as plt
url = Spenning.csv
data = np.readtxt(url,delimmeter = ';')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 url = Spenning.csv
#       4 data = np.readtxt(url,delimmeter = ';')
#
# NameError: name 'Spenning' is not defined
